# %%
# check notes

# https://huggingface.co/philschmid/donut-base-sroie

# %%
from datasets import load_dataset, Dataset
ds = load_dataset("rth/sroie-2019-v2")

# %%
ds['test'][0]['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=463x894>

# %%
ds['test'][0]['objects'].keys()
# Out:
# dict_keys(['bbox', 'text', 'entities'])

# %%
ds['test'][0]['objects']['entities']
# Out:
# {'company': 'OJC MARKETING SDN BHD',
#  'date': '15/01/2019',
#  'address': 'NO 2 & 4, JALAN BAYU 4, BANDAR SERI ALAM, B1750 MASAI, JOHOR',
#  'total': '193.00'}
